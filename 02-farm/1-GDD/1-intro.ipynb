# %% [markdown]
# # Project - Predict plant growth with IoT
#
#
# ![Alt Text](https://github.com/microsoft/IoT-For-Beginners/blob/main/sketchnotes/lesson-5.jpg?raw=true)
# ![Alt Text](https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExa21yNGl4ZmNrZjMxZmVpZDduYzAyYzlicDR1ajlybW5wNnh4d3hnMyZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/xdkXW7Scx6gus/giphy.webp)
#
# > Sketchnote by [Nitya Narasimhan](https://github.com/nitya). Click the image for a larger version.

# %% [markdown]
# ## Introdução
#
# > As plantas precisam de certas coisas para crescer - água, dióxido de carbono, nutrientes, luz e calor.
#
# > Nesta lição, você aprenderá a calcular as taxas de crescimento e maturidade das plantas medindo a temperatura do ar.
#
# Nesta lição abordaremos:
#
# * [Agricultura digital](#agricultura-digital)
# * [Por que a temperatura é importante na agricultura?](#por-que-a-temperatura-é-importante-na-agricultura)
# * [Medir temperatura ambiente](#measure-ambient-temperature)
# * [Graus-dias de crescimento (GDD)](#growing-degree-days)
# * [Calcular GDD usando dados do sensor de temperatura](#calculate-gdd-using-temperature-sensor-data)

# %% [markdown]
# ## Agricultura digital
#
#
#
# ![Alt Text](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExdWJuaW8xeDE1ZzMzbzY5eWc2a21wdDhvNWd5OGwwaGpldXIwejdtNSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/h5itFjRMWtvWAxfI5Y/giphy.webp)
#
#
#
# A Agricultura Digital está transformando a forma como cultivamos, usando ferramentas para coletar, armazenar e analisar dados da agricultura.
#
# Estamos atualmente em um período descrito como a "Quarta Revolução Industrial" pelo Fórum Econômico Mundial,
#
# e a ascensão da agricultura digital foi rotulada como a **"Quarta Revolução Agrícola"** ou **"Agricultura 4.0"**.
#
#
#
# > 🎓 O termo Agricultura Digital também inclui toda a 'cadeia de valor agrícola', ou seja, toda a jornada da fazenda à mesa. Inclui o rastreamento da qualidade dos produtos à medida que os alimentos são enviados e processados, sistemas de depósito e comércio eletrônico, até mesmo aplicativos de aluguel de tratores!
#
#
#
# Essas mudanças permitem que os agricultores aumentem a produção, usem menos fertilizantes e pesticidas e reguem com mais eficiência. Embora usados ​​principalmente em nações mais ricas, sensores e outros dispositivos estão lentamente reduzindo de preço, tornando-os mais acessíveis em nações em desenvolvimento.
#
#
#
# Algumas técnicas possibilitadas pela agricultura digital são:
#
#
#
# * Medição de temperatura - a medição da temperatura permite que os agricultores prevejam o crescimento e a maturidade das plantas.
#
# * Rega automatizada - medindo a umidade do solo e ligando os sistemas de irrigação quando o solo estiver muito seco, em vez de irrigação programada. A irrigação programada pode levar a plantações com pouca água durante um período quente e seco, ou com excesso de água durante a chuva. Ao regar apenas quando o solo precisa, os agricultores podem otimizar o uso da água.
#
# * Controle de pragas - os agricultores podem usar câmeras em robôs automatizados ou drones para verificar se há pragas e, então, aplicar pesticidas somente onde necessário, reduzindo a quantidade de pesticidas usados ​​e o escoamento de pesticidas nos suprimentos de água locais.
#
#
#
# ✅ Faça alguma pesquisa. Quais outras técnicas são usadas para melhorar os rendimentos agrícolas?
#
#
#
# > 🎓 O termo 'Agricultura de Precisão' é usado para definir a observação, medição e resposta a culturas em uma base por campo, ou mesmo em partes de um campo. Isso inclui medir níveis de água, nutrientes e pragas e responder com precisão, como regar apenas uma pequena parte de um campo.

# %% [markdown]
# ## Por que a temperatura é importante na agricultura?
#
# * Ao aprender sobre plantas, a maioria dos alunos aprende sobre a necessidade de água, luz, dióxido de carbono (CO<sub>2</sub>) e nutrientes.
# * As plantas também precisam de calor para crescer
#     * É por isso que as plantas florescem na primavera quando a temperatura sobe, por que os flocos de neve ou narcisos podem brotar cedo devido a uma curta onda de calor e por que estufas são tão boas em fazer as plantas crescerem.
#
# > 🎓 Estufas e estufas fazem um trabalho similar, mas com uma diferença importante. Estufas são aquecidas artificialmente e permitem que fazendeiros controlem temperaturas com mais precisão. Estufas dependem do sol para aquecimento e geralmente o único controle são janelas ou outras aberturas para deixar o calor sair.
#
# ![Alt Text](https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExeXpueXRwNDhkbG5sYm9icnl5bXhrcDVlajZmanF1NHp3cmpyaDBlYSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/gll2gG5rxZOgmS4cir/giphy.webp)
#
# As plantas têm uma temperatura base ou mínima, uma temperatura ótima e uma temperatura máxima, todas baseadas nas temperaturas médias diárias.
#
# * Temperatura base - é a temperatura média diária mínima necessária para uma planta crescer.
# * Temperatura ideal - esta é a melhor temperatura média diária para obter o máximo crescimento.
# * Temperatura máxima - Esta é a temperatura máxima que uma planta pode suportar. Acima disso, a planta interromperá seu crescimento em uma tentativa de conservar água e permanecer viva.
#
# > 💁 Essas são temperaturas médias, calculadas sobre as temperaturas diurnas e noturnas. As plantas também precisam de temperaturas diferentes durante o dia e a noite para ajudá-las a fotossintetizar com mais eficiência e economizar energia à noite.
#
# Cada espécie de planta tem valores diferentes para sua base, ótimo e máximo. É por isso que algumas plantas prosperam em países quentes, e outras em países mais frios.
#
# ✅ Faça alguma pesquisa. Para qualquer planta que você tenha em seu jardim, escola ou parque local, veja se consegue encontrar a temperatura base.
#
# ![Um gráfico mostrando a taxa de crescimento aumentando conforme a temperatura sobe, e depois diminuindo conforme a temperatura sobe muito](https://github.com/microsoft/IoT-For-Beginners/blob/main/images/plant-growth-temp-graph.png?raw=true)
#
#
# O gráfico acima mostra um exemplo de taxa de crescimento para gráfico de temperatura.
# * Até a temperatura base não há crescimento.
# * A taxa de crescimento aumenta até a temperatura ótima, então cai após atingir esse pico.
# * Na temperatura máxima o crescimento para.
#
# O formato deste gráfico varia de espécie de planta para espécie de planta. Algumas têm quedas mais acentuadas acima do ótimo, algumas têm aumentos mais lentos da base para o ótimo.
#
# > 💁 Para que um agricultor obtenha o melhor crescimento, ele precisará conhecer os três valores de temperatura e entender o formato dos gráficos das plantas que está cultivando.
#
# Se um fazendeiro tem controle de temperatura, por exemplo, em uma estufa comercial, então ele pode otimizar para suas plantas. Uma estufa comercial cultivando tomates, por exemplo, terá a temperatura ajustada para cerca de 25°C durante o dia e 20°C à noite para obter o crescimento mais rápido.
#
# > 🍅 A combinação dessas temperaturas com luzes artificiais, fertilizantes e níveis controlados de CO<sub>2</sub> significa que os produtores comerciais podem cultivar e colher o ano todo.
#
# ![Alt Text](https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExeDE4d3JzdXFpNGUybW42cjBucG5mMzBicXprZ3Fhaml0N3N4ajhsdSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/xT5LMw1X2Kldby93A4/giphy.webp)

# %% [markdown]
# ## Medir a temperatura ambiente
#
# Sensores de temperatura podem ser usados ​​com dispositivos IoT para medir a temperatura ambiente.
# ![image-2.png](attachment:image-2.png)
#
#
# ### Tarefa - medir temperatura
#
# Siga o guia relevante para monitorar temperaturas usando seu dispositivo IoT:
#
# * [Arduino - Terminal Wio](https://github.com/microsoft/IoT-For-Beginners/blob/main/2-farm/lessons/1-predict-plant-growth/wio-terminal-temp.md)
# * [Computador de placa única - Raspberry Pi](https://github.com/microsoft/IoT-For-Beginners/blob/main/2-farm/lessons/1-predict-plant-growth/pi-temp.md)
# * [Computador de placa única - Dispositivo virtual](https://github.com/microsoft/IoT-For-Beginners/blob/main/2-farm/lessons/1-predict-plant-growth/virtual-device-temp.md)

# %% [markdown]
# # Iremos usar o dispositivo virtual!

# %% [markdown]
# ## Hardware Virtual
#
# O dispositivo IoT virtual usará um sensor Grove Digital Humidity and Temperature simulado. Isso mantém este laboratório igual ao uso de um Raspberry Pi com um sensor Grove DHT11 físico.
#
# * O sensor combina um **sensor de temperatura** com um **sensor de umidade**, mas neste laboratório você está interessado apenas no componente do sensor de temperatura.
# * Em um dispositivo IoT físico, o sensor de temperatura seria um [termistor](https://wikipedia.org/wiki/Thermistor) que mede a temperatura detectando uma mudança na resistência conforme a temperatura muda.
# * Sensores de temperatura geralmente são sensores digitais que convertem internamente a resistência medida em uma temperatura em graus Celsius (ou Kelvin, ou Fahrenheit).
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Adicione os sensores ao CounterFit
#
# Para usar um sensor virtual de umidade e temperatura, você precisa adicionar os dois sensores ao aplicativo CounterFit
#
# #### Tarefa - adicionar os sensores ao CounterFit
#
# Adicione os sensores de umidade e temperatura ao aplicativo CounterFit.
#
# 1. Crie um novo aplicativo Python no seu computador em uma pasta chamada `temperature-sensor` com um único arquivo chamado `app.py` e um ambiente virtual Python e adicione os pacotes pip do CounterFit.
#
#     > ⚠️ Você pode consultar [as instruções para criar e configurar um projeto CounterFit Python na lição 1, se necessário](https://github.com/microsoft/IoT-For-Beginners/blob/main/1-getting-started/lessons/1-introduction-to-iot/virtual-device.md).
#
# 1. Instale um pacote Pip adicional para instalar um calço CounterFit para o sensor DHT11. Certifique-se de que você está instalando isso de um terminal com o ambiente virtual ativado.
#
#     ```sh
#     pip install counterfit-shims-seeed-python-dht
#     ```
#
# 1. Certifique-se de que o aplicativo CounterFit esteja em execução
#
# 1. Crie um sensor de umidade:
#
#     1. Na caixa *Criar sensor* no painel *Sensores*, abra a caixa *Tipo de sensor* e selecione *Umidade*.
#
#     1. Deixe as *Unidades* definidas como *Porcentagem*
#
#     1. Certifique-se de que o *Pin* esteja definido como *5*
#
#     1. Selecione o botão **Adicionar** para criar o sensor de umidade no pino 5
#
#     ![As configurações do sensor de umidade](https://github.com/microsoft/IoT-For-Beginners/raw/main/images/counterfit-create-humidity-sensor.png)
#
#     O sensor de umidade será criado e aparecerá na lista de sensores.
#
#     ![O sensor de umidade criado](https://github.com/microsoft/IoT-For-Beginners/raw/main/images/counterfit-humidity-sensor.png)
#
# 1. Crie um sensor de temperatura:
#
#     1. Na caixa *Criar sensor* no painel *Sensores*, abra a caixa *Tipo de sensor* e selecione *Temperatura*.
#
#     1. Deixe as *Unidades* definidas como *Celsius*
#
#     1. Certifique-se de que o *Pin* esteja definido como *6*
#
#     1. Selecione o botão **Adicionar** para criar o sensor de temperatura no pino 6
#
#     ![As configurações do sensor de temperatura](https://github.com/microsoft/IoT-For-Beginners/raw/main/images/counterfit-create-temperature-sensor.png)
#
#     O sensor de temperatura será criado e aparecerá na lista de sensores.
#
#     ![O sensor de temperatura criado](https://github.com/microsoft/IoT-For-Beginners/raw/main/images/counterfit-temperature-sensor.png)

# %% [markdown]
# ## Programe o aplicativo do sensor de temperatura
#
# O aplicativo do sensor de temperatura agora pode ser programado usando os sensores CounterFit.
#
# ### Tarefa - programar o aplicativo do sensor de temperatura
#
# Programe o aplicativo do sensor de temperatura.
#
# 1. Certifique-se de que o aplicativo `temperature-sensor` esteja aberto no VS Code
#
# 1. Abra o arquivo `app.py`
#
# 1. Adicione o seguinte código ao topo de `app.py` para conectar o aplicativo ao CounterFit:
#
#     ```Python
#     from counterfit_connection import CounterFitConnection
#     CounterFitConnection.init('127.0.0.1', 5001)
#     ```

# %%
from counterfit_connection import CounterFitConnection
CounterFitConnection.init('127.0.0.1', 5001)

# %% [markdown]
# 1. Adicione o seguinte código ao arquivo `app.py` para importar as bibliotecas necessárias:
#
#     ```Python
#     import time
#     from counterfit_shims_seeed_python_dht import DHT
#     ```
#
#     A instrução `from seeed_dht import DHT` importa a classe de sensor `DHT` para interagir com um sensor de temperatura Grove virtual usando um shim do módulo `counterfit_shims_seeed_python_dht`.

# %%
import time
from counterfit_shims_seeed_python_dht import DHT

# %% [markdown]
# 1. Adicione o seguinte código após o código acima para criar uma instância da classe que gerencia o sensor virtual de umidade e temperatura:
#
#     ```Python
#     sensor = DHT("11", 5)
#     ```
#
#     Isto declara uma instância da classe `DHT` que gerencia o sensor virtual **D**igital **H**umidity and **T**emperature. O primeiro parâmetro informa que o sensor que está sendo usado é um sensor virtual *DHT11*. O segundo parâmetro informa que o sensor está conectado à porta `5`.
#
#     > 💁 O CounterFit simula esse sensor combinado de umidade e temperatura conectando-se a 2 sensores, um sensor de umidade no pino fornecido quando a classe `DHT` é criada e um sensor de temperatura que roda no próximo pino. Se o sensor de umidade estiver no pino 5, o shim espera que o sensor de temperatura esteja no pino 6.

# %%
sensor = DHT("11", 5)

# %% [markdown]
# 1. Adicione um loop infinito após o código acima para consultar o valor do sensor de temperatura e imprimi-lo no console:
#
#     ```Python
#     while True:
#         _, temp = sensor.read()
#         print(f'Temperature {temp}°C')
#     ```
#
#     A chamada para `sensor.read()` retorna uma tupla de umidade e temperatura. Você só precisa do valor da temperatura, então a umidade é ignorada. O valor da temperatura é então impresso no console.

# %%
while True:
    _, temp = sensor.read()
    print(f'Temperature {temp}°C')
# Out:
# Temperature 17.63°C
# Temperature 26.41°C
# Temperature 36.25°C
# Temperature 22.3°C
# Temperature 7.26°C
# Temperature 31.75°C
# Temperature 18.34°C
# Temperature 22.98°C
# Temperature 6.56°C
# Temperature 35.19°C
# Temperature 32.14°C
# Temperature 18.62°C
# Temperature 34.41°C
# Temperature 33.79°C
# Temperature 2.46°C
# Temperature 34.43°C
# Temperature 23.98°C
# Temperature 11.97°C
# Temperature 15.71°C
# Temperature 29.48°C
# Temperature 7.71°C
# Temperature 5.71°C
# Temperature 14.56°C
# Temperature 28.49°C
# Temperature 22.47°C
# Temperature 7.3°C
# Temperature 29.52°C
# Temperature 25.18°C
# Temperature 31.53°C
# Temperature 31.2°C
# Temperature 34.17°C
# Temperature 7.45°C
# Temperature 32.31°C
# Temperature 38.91°C
# Temperature 32.16°C
# Temperature 13.47°C
# Temperature 34.68°C
# Temperature 31.76°C
# Temperature 33.33°C
# Temperature 24.67°C
# Temperature 29.3°C
# Temperature 15.13°C
# Temperature 15.73°C
# Temperature 29.63°C
# Temperature 7.73°C
# Temperature 2.59°C
# Temperature 7.38°C
# Temperature 25.27°C
# Temperature 25.12°C
# Temperature 2.51°C
# Temperature 28.65°C
# Temperature 30.38°C
# Temperature 35.2°C
# Temperature 1.68°C
# Temperature 31.67°C
# Temperature 2.06°C
# Temperature 35.09°C
# Temperature 33.49°C
# Temperature 29.08°C
# Temperature 16.09°C
# Temperature 2.45°C
# Temperature 21.2°C
# Temperature 4.07°C
# Temperature 29.69°C
# Temperature 6.48°C
# Temperature 33.36°C
# Temperature 8.53°C
# Temperature 18.46°C
# Temperature 1.24°C
# Temperature 13.18°C
# Temperature 0.65°C
# Temperature 9.25°C
# Temperature 25.28°C
# Temperature 22.71°C
# Temperature 9.23°C
# Temperature 38.76°C
# Temperature 6.86°C
# Temperature 2.85°C
# Temperature 21.89°C
# Temperature 9.72°C
# Temperature 31.24°C
# Temperature 35.44°C
# Temperature 2.53°C
# Temperature 11.99°C
# Temperature 28.5°C
# Temperature 5.15°C
# Temperature 3.42°C
# Temperature 25.12°C
# Temperature 31.53°C
# Temperature 39.11°C
# Temperature 32.9°C
# Temperature 19.64°C
# Temperature 29.69°C
# Temperature 2.59°C
# Temperature 20.49°C
# Temperature 2.62°C
# Temperature 6.05°C
# Temperature 21.85°C
# Temperature 23.78°C
# Temperature 31.96°C
# Temperature 28.6°C
# Temperature 38.58°C
# Temperature 34.12°C
# Temperature 8.83°C
# Temperature 24.24°C
# Temperature 17.27°C
# Temperature 2.9°C
# Temperature 5.59°C
# Temperature 21.7°C
# Temperature 3.17°C
# Temperature 8.4°C
# Temperature 28.0°C
# Temperature 24.32°C
# Temperature 4.51°C
# Temperature 37.62°C
# Temperature 0.68°C
# Temperature 5.08°C
# Temperature 29.82°C
# Temperature 31.74°C
# Temperature 37.57°C
# Temperature 15.12°C
# Temperature 18.71°C
# Temperature 34.95°C
# Temperature 31.92°C
# Temperature 29.05°C
# Temperature 2.78°C
# Temperature 19.26°C
# Temperature 30.3°C
# Temperature 29.38°C
# Temperature 8.25°C
# Temperature 22.73°C
# Temperature 24.1°C
# Temperature 32.94°C
# Temperature 13.1°C
# Temperature 23.25°C
# Temperature 19.06°C
# Temperature 35.51°C
# Temperature 10.98°C
# Temperature 23.51°C
# Temperature 1.23°C
# Temperature 30.08°C
# Temperature 22.85°C
# Temperature 30.41°C
# Temperature 36.31°C
# Temperature 31.03°C
# Temperature 6.91°C
# Temperature 0.98°C
# Temperature 21.31°C
# Temperature 26.74°C
# Temperature 31.49°C
# Temperature 18.14°C
# Temperature 33.26°C
# Temperature 30.67°C
# Temperature 38.63°C
# Temperature 11.24°C
# Temperature 11.22°C
# Temperature 8.04°C
# Temperature 18.31°C
# Temperature 13.94°C
# Temperature 24.14°C
# Temperature 22.95°C
# Temperature 32.39°C
# Temperature 31.57°C
# Temperature 34.78°C
# Temperature 23.8°C
# Temperature 16.21°C
# Temperature 22.73°C
# Temperature 0.38°C
# Temperature 35.03°C
# Temperature 6.79°C
# Temperature 36.46°C
# Temperature 24.73°C
# Temperature 11.28°C
# Temperature 20.93°C
# Temperature 33.86°C
# Temperature 3.79°C
# Temperature 38.53°C
# Temperature 31.38°C
# Temperature 31.88°C
# Temperature 12.17°C
# Temperature 20.46°C
# Temperature 24.69°C
# Temperature 22.06°C
# Temperature 3.74°C
# Temperature 1.68°C
# Temperature 9.78°C
# Temperature 24.06°C
# Temperature 4.96°C
# Temperature 35.08°C
# Temperature 1.74°C
# Temperature 2.44°C
# Temperature 3.61°C
# Temperature 10.58°C
# Temperature 31.61°C
# Temperature 0.34°C
# Temperature 36.03°C
# Temperature 0.95°C
# Temperature 34.74°C
# Temperature 23.47°C
# Temperature 17.86°C
# Temperature 16.33°C
# Temperature 32.44°C
# Temperature 21.34°C
# Temperature 35.45°C
# Temperature 24.72°C
# Temperature 3.75°C
# Temperature 32.51°C
# Temperature 1.81°C
# Temperature 23.98°C
# Temperature 25.86°C
# Temperature 15.47°C
# Temperature 21.01°C
# Temperature 1.76°C
# Temperature 32.11°C
# Temperature 5.77°C
# Temperature 32.25°C
# Temperature 7.95°C
# Temperature 14.58°C
# Temperature 0.53°C
# Temperature 1.41°C
# Temperature 14.15°C
# Temperature 35.21°C
# Temperature 11.66°C
# Temperature 39.68°C
# Temperature 0.7°C
# Temperature 30.72°C
# Temperature 31.77°C
# Temperature 9.74°C
# Temperature 20.43°C
# Temperature 30.04°C
# Temperature 6.88°C
# Temperature 13.96°C
# Temperature 36.68°C
# Temperature 27.08°C
# Temperature 34.1°C
# Temperature 4.45°C
# Temperature 2.71°C
# Temperature 22.21°C
# Temperature 17.72°C
# Temperature 7.35°C
# Temperature 34.75°C
# Temperature 22.72°C
# Temperature 39.46°C
# Temperature 2.12°C
# Temperature 35.12°C
# Temperature 37.18°C
# Temperature 36.83°C
# Temperature 39.94°C
# Temperature 30.97°C
# Temperature 26.98°C
# Temperature 12.96°C
# Temperature 36.72°C
# Temperature 38.91°C
# Temperature 17.52°C
# Temperature 8.92°C
# Temperature 4.85°C
# Temperature 5.09°C
# Temperature 2.85°C
# Temperature 39.95°C
# Temperature 15.84°C
# Temperature 13.43°C
# Temperature 37.74°C
# Temperature 31.32°C
# Temperature 10.17°C
# Temperature 13.23°C
# Temperature 12.6°C
# Temperature 0.48°C
# Temperature 38.43°C
# Temperature 11.03°C
# Temperature 19.82°C
# Temperature 35.82°C
# Temperature 22.29°C
# Temperature 12.05°C
# Temperature 7.67°C
# Temperature 33.44°C
# Temperature 34.03°C
# Temperature 22.65°C
# Temperature 12.51°C
# Temperature 20.22°C
# Temperature 28.97°C
# Temperature 11.46°C
# Temperature 38.63°C
# Temperature 0.38°C
# Temperature 39.22°C
# Temperature 30.42°C
# Temperature 8.12°C
# Temperature 20.18°C
# Temperature 25.19°C
# Temperature 23.98°C
# Temperature 21.61°C
# Temperature 38.85°C
# Temperature 5.61°C
# Temperature 36.81°C
# Temperature 8.48°C
# Temperature 4.75°C
# Temperature 31.4°C
# Temperature 8.63°C
# Temperature 20.59°C
# Temperature 25.87°C
# Temperature 3.16°C
# Temperature 20.6°C
# Temperature 28.78°C
# Temperature 11.79°C
# Temperature 7.05°C
# Temperature 0.25°C
# Temperature 19.25°C
# Temperature 19.95°C
# Temperature 25.11°C
# Temperature 10.22°C
# Temperature 17.15°C
# Temperature 38.76°C
# Temperature 13.6°C
# Temperature 35.62°C
# Temperature 3.93°C
# Temperature 0.85°C
# Temperature 1.33°C
# Temperature 31.36°C
# Temperature 33.39°C
# Temperature 4.99°C
# Temperature 0.88°C
# Temperature 35.95°C
# Temperature 32.83°C
# Temperature 2.67°C
# Temperature 34.41°C
# Temperature 18.28°C
# Temperature 3.63°C
# Temperature 11.85°C
# Temperature 0.1°C
# Temperature 1.73°C
# Temperature 24.7°C
# Temperature 5.93°C
# Temperature 25.88°C
# Temperature 7.37°C
# Temperature 25.41°C
# Temperature 26.84°C
# Temperature 15.73°C
# Temperature 2.93°C
# Temperature 3.6°C
# Temperature 30.35°C
# Temperature 30.66°C
# Temperature 18.26°C
# Temperature 34.18°C
# Temperature 15.22°C
# Temperature 12.56°C
# Temperature 12.21°C
# Temperature 22.32°C
# Temperature 12.65°C
# Temperature 25.34°C
# Temperature 23.51°C
# Temperature 7.41°C
# Temperature 37.95°C
# Temperature 20.74°C
# Temperature 28.56°C
# Temperature 15.98°C
# Temperature 5.41°C
# Temperature 28.17°C
# Temperature 20.02°C
# Temperature 37.25°C
# Temperature 25.78°C
# Temperature 33.92°C
# Temperature 29.54°C
# Temperature 28.56°C
# Temperature 14.94°C
# Temperature 23.06°C
# Temperature 7.08°C
# Temperature 10.78°C
# Temperature 31.05°C
# Temperature 3.43°C
# Temperature 4.28°C
# Temperature 32.89°C
# Temperature 13.94°C
# Temperature 38.59°C
# Temperature 7.71°C
# Temperature 24.79°C
# Temperature 25.97°C
# Temperature 11.36°C
# Temperature 35.74°C
# Temperature 16.55°C
# Temperature 28.97°C
# Temperature 13.63°C
# Temperature 24.26°C
# Temperature 1.92°C
# Temperature 6.39°C
# Temperature 17.13°C
# Temperature 2.73°C
# Temperature 22.9°C
# Temperature 5.83°C
# Temperature 28.77°C
# Temperature 35.22°C
# Temperature 15.42°C
# Temperature 7.62°C
# Temperature 20.86°C
# Temperature 9.6°C
# Temperature 38.4°C
# Temperature 29.49°C
# Temperature 7.44°C
# Temperature 15.49°C
# Temperature 1.48°C
# Temperature 28.65°C
# Temperature 7.85°C
# Temperature 23.54°C
# Temperature 6.27°C
# Temperature 12.47°C
# Temperature 38.38°C
# Temperature 27.85°C
# Temperature 16.78°C
# Temperature 26.61°C
# Temperature 24.44°C
# Temperature 1.4°C
# Temperature 22.48°C
# Temperature 32.75°C
# Temperature 25.09°C
# Temperature 8.11°C
# Temperature 19.82°C
# Temperature 27.64°C
# Temperature 18.73°C
# Temperature 12.39°C
# Temperature 18.05°C
# Temperature 16.04°C
# Temperature 18.23°C
# Temperature 30.97°C
# Temperature 19.37°C
# Temperature 4.92°C
# Temperature 25.46°C
# Temperature 22.79°C
# Temperature 37.21°C
# Temperature 19.12°C
# Temperature 11.23°C
# Temperature 13.07°C
# Temperature 12.66°C
# Temperature 27.26°C
# Temperature 20.03°C
# Temperature 17.06°C
# Temperature 31.42°C
# Temperature 8.98°C
# Temperature 33.52°C
# Temperature 0.71°C
# Temperature 36.82°C
# Temperature 34.54°C
# Temperature 13.24°C
# Temperature 7.93°C
# Temperature 11.03°C
# Temperature 10.81°C
# Temperature 7.95°C
# Temperature 35.97°C
# Temperature 16.65°C
# Temperature 31.92°C
# Temperature 20.08°C
# Temperature 23.36°C
# Temperature 22.14°C
# Temperature 20.73°C
# Temperature 30.2°C
# Temperature 23.83°C
# Temperature 22.96°C
# Temperature 6.97°C
# Temperature 5.08°C
# Temperature 0.21°C
# Temperature 8.48°C
# Temperature 26.73°C
# Temperature 15.04°C
# Temperature 21.52°C
# Temperature 29.62°C
# Temperature 21.52°C
# Temperature 18.99°C
# Temperature 11.71°C
# Temperature 16.39°C
# Temperature 22.15°C
# Temperature 22.43°C
# Temperature 25.54°C
# Temperature 12.77°C
# Temperature 6.72°C
# Temperature 30.56°C
# Temperature 38.5°C
# Temperature 18.3°C
# Temperature 4.61°C
# Temperature 23.21°C
# Temperature 2.59°C
# Temperature 26.77°C
# Temperature 34.78°C
# Temperature 3.1°C
# Temperature 25.2°C
# Temperature 25.33°C
# Temperature 13.25°C
# Temperature 20.18°C
# Temperature 32.93°C
# Temperature 37.07°C
# Temperature 38.64°C
# Temperature 38.36°C
# Temperature 23.09°C
# Temperature 2.14°C
# Temperature 19.81°C
# Temperature 23.0°C
# Temperature 11.34°C
# Temperature 8.19°C
# Temperature 38.45°C
# Temperature 38.96°C
# Temperature 27.3°C
# Temperature 24.91°C
# Temperature 32.85°C
# Temperature 32.44°C
# Temperature 16.34°C
# Temperature 29.57°C
# Temperature 28.66°C
# Temperature 0.21°C
# Temperature 17.23°C
# Temperature 29.84°C
# Temperature 5.85°C
# Temperature 1.51°C
# Temperature 8.52°C
# Temperature 31.2°C
# Temperature 31.16°C
# Temperature 33.67°C
# Temperature 22.41°C
# Temperature 25.31°C
# Temperature 5.78°C
# Temperature 24.65°C
# Temperature 25.5°C
# Temperature 16.43°C
# Temperature 6.77°C
# Temperature 6.14°C
# Temperature 31.81°C
# Temperature 27.65°C
# Temperature 22.75°C
# Temperature 18.48°C
# Temperature 20.2°C
# Temperature 26.88°C
# Temperature 5.95°C
# Temperature 19.35°C
# Temperature 24.5°C
# Temperature 20.09°C
# Temperature 16.94°C
# Temperature 25.45°C
# Temperature 23.46°C
# Temperature 11.37°C
# Temperature 16.68°C
# Temperature 36.84°C
# Temperature 5.12°C
# Temperature 36.65°C
# Temperature 20.3°C
# Temperature 24.69°C
# Temperature 3.68°C
# Temperature 27.75°C
# Temperature 34.39°C
# Temperature 29.83°C
# Temperature 33.33°C
# Temperature 11.81°C
# Temperature 15.45°C
# Temperature 3.62°C
# Temperature 13.99°C
# Temperature 33.12°C
# Temperature 5.52°C
# Temperature 1.3°C
# Temperature 32.14°C
# Temperature 25.92°C
# Temperature 7.59°C
# Temperature 33.11°C
# Temperature 13.01°C
# Temperature 0.02°C
# Temperature 21.08°C
# Temperature 37.43°C
# Temperature 36.21°C
# Temperature 33.0°C
# Temperature 37.89°C
# Temperature 17.74°C
# Temperature 21.56°C
# Temperature 28.24°C
# Temperature 38.36°C
# Temperature 37.17°C
# Temperature 1.9°C
# Temperature 14.78°C
# Temperature 30.23°C
# Temperature 16.37°C
# Temperature 1.3°C
# Temperature 20.97°C
# Temperature 36.05°C
# Temperature 5.31°C
# Temperature 7.81°C
# Temperature 38.03°C
# Temperature 11.79°C
# Temperature 22.9°C
# Temperature 10.71°C
# Temperature 9.04°C
# Temperature 12.74°C
# Temperature 38.2°C
# Temperature 38.77°C
# Temperature 7.5°C
# Temperature 34.72°C
# Temperature 29.46°C
# Temperature 10.33°C
# Temperature 13.98°C
# Temperature 37.31°C
# Temperature 4.54°C
# Temperature 21.68°C
# Temperature 11.32°C
# Temperature 5.54°C
# Temperature 19.73°C
# Temperature 16.35°C
# Temperature 22.27°C
# Temperature 26.5°C
# Temperature 35.51°C
# Temperature 39.29°C
# Temperature 22.54°C
# Temperature 26.34°C
# Temperature 37.22°C
# Temperature 22.25°C
# Temperature 23.22°C
# Temperature 34.56°C
# Temperature 31.93°C
# Temperature 26.2°C
# Temperature 34.1°C
# Temperature 30.5°C
# Temperature 3.89°C
# Temperature 15.19°C
# Temperature 9.19°C
# Temperature 1.2°C
# Temperature 39.95°C
# Temperature 31.27°C
# Temperature 34.85°C
# Temperature 16.26°C
# Temperature 14.24°C
# Temperature 36.52°C
# Temperature 12.06°C
# Temperature 16.23°C
# Temperature 38.95°C
# Temperature 0.4°C
# Temperature 6.17°C
# Temperature 1.72°C
# Temperature 37.63°C
# Temperature 4.63°C
# Temperature 2.95°C
# Temperature 29.28°C
# Temperature 9.9°C
# Temperature 21.67°C
# Temperature 31.39°C
# Temperature 18.37°C
# Temperature 19.43°C
# Temperature 34.67°C
# Temperature 16.47°C
# Temperature 20.95°C
# Temperature 12.04°C
# Temperature 2.28°C
# Temperature 16.3°C
# Temperature 1.83°C
# Temperature 30.98°C
# Temperature 25.32°C
# Temperature 13.03°C
# Temperature 15.5°C
# Temperature 25.73°C
# Temperature 12.55°C
# Temperature 1.31°C
# Temperature 13.13°C
# Temperature 5.5°C
# Temperature 3.89°C
# Temperature 30.61°C
# Temperature 11.58°C
# Temperature 20.73°C
# Temperature 12.96°C
# Temperature 34.05°C
# Temperature 29.23°C
# Temperature 11.39°C
# Temperature 3.98°C
# Temperature 1.36°C
# Temperature 20.73°C
# Temperature 9.51°C
# Temperature 12.43°C
# Temperature 29.96°C
# Temperature 36.6°C
# Temperature 11.33°C
# Temperature 18.67°C
# Temperature 30.94°C
# Temperature 10.92°C
# Temperature 3.74°C
# Temperature 0.68°C
# Temperature 23.05°C
# Temperature 1.34°C
# Temperature 24.95°C
# Temperature 25.62°C
# Temperature 11.93°C
# Temperature 19.96°C
# Temperature 4.62°C
# Temperature 13.46°C
# Temperature 6.31°C
# Temperature 39.91°C
# Temperature 25.15°C
# Temperature 9.7°C
# Temperature 34.09°C
# Temperature 18.57°C
# Temperature 22.73°C
# Temperature 21.16°C
# Temperature 38.84°C
# Temperature 18.08°C
# Temperature 20.89°C
# Temperature 32.69°C
# Temperature 25.27°C
# Temperature 21.74°C
# Temperature 33.13°C
# Temperature 17.15°C
# Temperature 15.8°C
# Temperature 9.27°C
# Temperature 21.53°C
# Temperature 27.55°C
# Temperature 35.54°C
# Temperature 17.7°C
# Temperature 13.43°C
# Temperature 3.0°C
# Temperature 5.07°C
# Temperature 8.41°C
# Temperature 9.81°C
# Temperature 37.02°C
# Temperature 21.14°C
# Temperature 25.81°C
# Temperature 38.93°C
# Temperature 38.54°C
# Temperature 33.08°C
# Temperature 22.3°C
# Temperature 21.51°C
# Temperature 2.39°C
# Temperature 27.96°C
# Temperature 31.07°C
# Temperature 20.88°C
# Temperature 23.6°C
# Temperature 21.83°C
# Temperature 12.24°C
# Temperature 34.32°C
# Temperature 3.12°C
# Temperature 16.33°C
# Temperature 20.86°C
# Temperature 8.03°C
# Temperature 15.35°C
# Temperature 27.84°C
# Temperature 0.29°C
# Temperature 22.02°C
# Temperature 1.24°C
# Temperature 36.14°C
# Temperature 16.13°C
# Temperature 35.7°C
# Temperature 19.48°C
# Temperature 23.24°C
# Temperature 23.65°C
# Temperature 1.04°C
# Temperature 1.02°C
# Temperature 3.79°C
# Temperature 25.9°C
# Temperature 7.42°C
# Temperature 14.86°C
# Temperature 23.44°C
# Temperature 30.93°C
# Temperature 15.83°C
# Temperature 12.87°C
# Temperature 16.17°C
# Temperature 24.2°C
# Temperature 17.41°C
# Temperature 36.02°C
# Temperature 38.0°C
# Temperature 0.81°C
# Temperature 29.53°C
# Temperature 11.44°C
# Temperature 1.43°C
# Temperature 7.8°C
# Temperature 12.1°C
# Temperature 14.4°C
# Temperature 17.48°C
# Temperature 0.1°C
# Temperature 12.18°C
# Temperature 5.98°C
# Temperature 11.57°C
# Temperature 22.82°C
# Temperature 9.55°C
# Temperature 31.72°C
# Temperature 2.74°C
# Temperature 27.43°C
# Temperature 15.02°C
# Temperature 0.08°C
# Temperature 24.4°C
# Temperature 23.25°C
# Temperature 37.0°C
# Temperature 13.92°C
# Temperature 0.5°C
# Temperature 30.46°C
# Temperature 4.98°C
# Temperature 0.29°C
# Temperature 3.98°C
# Temperature 29.0°C
# Temperature 0.86°C
# Temperature 34.21°C
# Temperature 21.58°C
# Temperature 30.71°C
# Temperature 22.03°C
# Temperature 20.04°C
# Temperature 1.6°C
# Temperature 25.96°C
# Temperature 7.0°C
# Temperature 16.3°C
# Temperature 29.0°C
# Temperature 26.01°C
# Temperature 1.65°C
# Temperature 11.4°C
# Temperature 28.12°C
# Temperature 8.59°C
# Temperature 33.68°C
# Temperature 29.13°C
# Temperature 36.26°C
# Temperature 22.39°C
# Temperature 4.14°C
# Temperature 14.13°C
# Temperature 10.48°C
# Temperature 32.84°C
# Temperature 20.95°C
# Temperature 21.31°C
# Temperature 9.66°C
# Temperature 0.61°C
# Temperature 32.41°C
# Temperature 34.84°C
# Temperature 32.87°C
# Temperature 12.42°C
# Temperature 28.55°C
# Temperature 9.78°C
# Temperature 38.71°C
# Temperature 37.54°C
# Temperature 20.71°C
# Temperature 12.42°C
# Temperature 39.03°C
# Temperature 24.12°C
# Temperature 28.53°C
# Temperature 28.14°C
# Temperature 27.5°C
# Temperature 23.1°C
# Temperature 15.28°C
# Temperature 21.79°C
# Temperature 16.89°C
# Temperature 8.25°C
# Temperature 37.15°C
# Temperature 9.75°C
# Temperature 19.63°C
# Temperature 32.8°C
# Temperature 38.66°C
# Temperature 28.64°C
# Temperature 1.99°C
# Temperature 30.68°C
# Temperature 7.54°C
# Temperature 27.95°C
# Temperature 7.12°C
# Temperature 19.84°C
# Temperature 26.74°C
# Temperature 2.12°C
# Temperature 35.25°C
# Temperature 18.01°C
# Temperature 27.72°C
# Temperature 34.47°C
# Temperature 6.37°C
# Temperature 24.62°C
# Temperature 24.64°C
# Temperature 38.63°C
# Temperature 3.74°C
# Temperature 19.79°C
# Temperature 31.48°C
# Temperature 17.34°C
# Temperature 21.96°C
# Temperature 16.28°C
# Temperature 34.37°C
# Temperature 13.85°C
# Temperature 2.08°C
# Temperature 12.84°C
# Temperature 5.4°C
# Temperature 13.82°C
# Temperature 20.96°C
# Temperature 15.12°C
# Temperature 31.39°C
# Temperature 2.73°C
# Temperature 15.32°C
# Temperature 5.23°C
# Temperature 16.62°C
# Temperature 29.66°C
# Temperature 18.63°C
# Temperature 25.67°C
# Temperature 18.4°C
# Temperature 27.68°C
# Temperature 1.58°C
# Temperature 2.48°C
# Temperature 11.65°C
# Temperature 5.48°C
# Temperature 12.82°C
# Temperature 15.7°C
# Temperature 20.85°C
# Temperature 18.31°C
# Temperature 7.36°C
# Temperature 6.27°C
# Temperature 0.71°C
# Temperature 4.37°C
# Temperature 38.46°C
# Temperature 7.47°C
# Temperature 13.23°C
# Temperature 38.06°C
# Temperature 22.53°C
# Temperature 2.87°C
# Temperature 20.97°C
# Temperature 14.63°C
# Temperature 38.12°C
# Temperature 34.54°C
# Temperature 7.1°C
# Temperature 34.27°C
# Temperature 39.47°C
# Temperature 5.66°C
# Temperature 13.87°C
# Temperature 27.75°C
# Temperature 29.92°C
# Temperature 33.06°C
# Temperature 34.42°C
# Temperature 2.68°C
# Temperature 14.07°C
# Temperature 5.8°C
# Temperature 1.42°C
# Temperature 35.01°C
# Temperature 27.04°C
# Temperature 32.82°C
# Temperature 27.73°C
# Temperature 11.45°C
# Temperature 9.2°C
# Temperature 38.38°C
# Temperature 2.27°C
# Temperature 16.19°C
# Temperature 22.67°C
# Temperature 9.21°C
# Temperature 30.46°C
# Temperature 11.76°C
# Temperature 32.21°C
# Temperature 2.67°C
# Temperature 24.99°C
# Temperature 1.3°C
# Temperature 3.57°C
# Temperature 11.3°C
# Temperature 25.85°C
# Temperature 1.32°C
# Temperature 19.86°C
# Temperature 0.84°C
# Temperature 12.0°C
# Temperature 7.75°C
# Temperature 3.26°C
# Temperature 19.34°C
# Temperature 34.86°C
# Temperature 10.6°C
# Temperature 11.24°C
# Temperature 33.57°C
# Temperature 33.45°C
# Temperature 38.24°C
# Temperature 17.43°C
# Temperature 39.36°C
# Temperature 14.21°C
# Temperature 30.1°C
# Temperature 34.43°C
# Temperature 27.09°C
# Temperature 35.13°C
# Temperature 32.42°C
# Temperature 34.35°C
# Temperature 36.84°C
# Temperature 6.32°C
# Temperature 32.04°C
# Temperature 30.87°C
# Temperature 21.3°C
# Temperature 37.41°C
# Temperature 30.63°C
# Temperature 37.76°C
# Temperature 5.14°C
# Temperature 27.62°C
# Temperature 2.83°C
# Temperature 22.82°C
# Temperature 15.32°C
# Temperature 39.55°C
# Temperature 14.17°C
# Temperature 12.19°C
# Temperature 25.72°C
# Temperature 16.85°C
# Temperature 25.65°C
# Temperature 38.65°C
# Temperature 16.84°C
# Temperature 20.2°C
# Temperature 31.17°C
# Temperature 10.88°C
# Temperature 5.25°C
# Temperature 10.98°C
# Temperature 13.31°C
# Temperature 33.17°C
# Temperature 16.5°C
# Temperature 15.42°C
# Temperature 1.23°C
# Temperature 14.59°C
# Temperature 2.55°C
# Temperature 30.16°C
# Temperature 2.04°C
# Temperature 24.26°C
# Temperature 4.94°C
# Temperature 27.27°C
# Temperature 11.65°C
# Temperature 17.16°C
# Temperature 18.49°C
# Temperature 23.75°C
# Temperature 28.84°C
# Temperature 25.32°C
# Temperature 1.95°C
# Temperature 18.95°C
# Temperature 15.28°C
# Temperature 36.25°C
# Temperature 27.73°C
# Temperature 31.63°C
# Temperature 31.35°C
# Temperature 30.12°C
# Temperature 25.2°C
# Temperature 2.95°C
# Temperature 5.89°C
# Temperature 39.38°C
# Temperature 26.37°C
# Temperature 34.4°C
# Temperature 27.1°C
# Temperature 17.62°C
# Temperature 35.64°C
# Temperature 8.45°C
# Temperature 2.17°C
# Temperature 34.13°C
# Temperature 16.61°C
# Temperature 10.56°C
# Temperature 10.71°C
# Temperature 29.61°C
# Temperature 18.58°C
# Temperature 0.82°C
# Temperature 31.14°C
# Temperature 28.48°C
# Temperature 39.15°C
# Temperature 30.16°C
# Temperature 32.68°C
# Temperature 2.55°C
# Temperature 31.13°C
# Temperature 37.7°C
# Temperature 16.03°C
# Temperature 21.39°C
# Temperature 33.7°C
# Temperature 21.53°C
# Temperature 33.93°C
# Temperature 33.2°C
# Temperature 16.32°C
# Temperature 0.49°C
# Temperature 35.1°C
# Temperature 1.67°C
# Temperature 31.48°C
# Temperature 20.14°C
# Temperature 17.95°C
# Temperature 11.65°C
# Temperature 24.71°C
# Temperature 39.6°C
# Temperature 24.33°C
# Temperature 30.76°C
# Temperature 31.68°C
# Temperature 11.73°C
# Temperature 6.0°C
# Temperature 30.16°C
# Temperature 11.68°C
# Temperature 36.24°C
# Temperature 14.52°C
# Temperature 15.47°C
# Temperature 32.8°C
# Temperature 12.42°C
# Temperature 15.3°C
# Temperature 28.38°C
# Temperature 35.81°C
# Temperature 26.31°C
# Temperature 14.19°C
# Temperature 18.79°C
# Temperature 6.01°C
# Temperature 20.05°C
# Temperature 17.96°C
# Temperature 36.48°C
# Temperature 26.38°C
# Temperature 27.13°C
# Temperature 25.5°C
# Temperature 16.99°C
# Temperature 31.95°C
# Temperature 19.55°C
# Temperature 31.31°C
# Temperature 8.55°C
# Temperature 1.72°C
# Temperature 33.53°C
# Temperature 22.45°C
# Temperature 9.78°C
# Temperature 3.59°C
# Temperature 29.66°C
# Temperature 21.87°C
# Temperature 1.12°C
# Temperature 32.61°C
# Temperature 13.41°C
# Temperature 19.6°C
# Temperature 10.56°C
# Temperature 15.17°C
# Temperature 24.35°C
# Temperature 2.92°C
# Temperature 33.97°C
# Temperature 30.5°C
# Temperature 0.29°C
# Temperature 2.72°C
# Temperature 5.54°C
# Temperature 16.51°C
# Temperature 6.82°C
# Temperature 7.68°C
# Temperature 35.24°C
# Temperature 17.59°C
# Temperature 36.17°C
# Temperature 2.54°C
# Temperature 18.28°C
# Temperature 12.68°C
# Temperature 9.53°C
# Temperature 23.66°C
# Temperature 27.19°C
# Temperature 4.1°C
# Temperature 25.87°C
# Temperature 33.46°C
# Temperature 19.16°C
# Temperature 15.67°C
# Temperature 38.76°C
# Temperature 26.9°C
# Temperature 29.37°C
# Temperature 20.13°C
# Temperature 2.07°C
# Temperature 38.24°C
# Temperature 16.27°C
# Temperature 3.36°C
# Temperature 33.7°C
# Temperature 24.02°C
# Temperature 14.98°C
# Temperature 21.35°C
# Temperature 0.49°C
# Temperature 36.03°C
# Temperature 31.3°C
# Temperature 7.94°C
# Temperature 13.82°C
# Temperature 14.39°C
# Temperature 17.79°C
# Temperature 23.28°C
# Temperature 35.76°C
# Temperature 30.84°C
# Temperature 15.97°C
# Temperature 16.91°C
# Temperature 12.46°C
# Temperature 38.4°C
# Temperature 18.24°C
# Temperature 14.27°C
# Temperature 37.99°C
# Temperature 6.01°C
# Temperature 28.55°C
# Temperature 34.03°C
# Temperature 22.79°C
# Temperature 15.94°C
# Temperature 6.68°C
# Temperature 23.8°C
# Temperature 17.29°C
# Temperature 22.67°C
# Temperature 11.07°C
# Temperature 16.38°C
# Temperature 38.98°C
# Temperature 22.73°C
# Temperature 29.52°C
# Temperature 7.28°C
# Temperature 14.09°C
# Temperature 34.67°C
# Temperature 39.22°C
# Temperature 37.37°C
# Temperature 17.41°C
# Temperature 8.17°C
# Temperature 22.85°C
# Temperature 27.46°C
# Temperature 25.29°C
# Temperature 35.98°C
# Temperature 37.16°C
# Temperature 14.25°C
# Temperature 24.81°C
# Temperature 37.42°C
# Temperature 8.88°C
# Temperature 35.25°C
# Temperature 14.43°C
# Temperature 20.25°C
# Temperature 7.62°C
# Temperature 9.46°C
# Temperature 16.04°C
# Temperature 16.91°C
# Temperature 23.47°C
# Temperature 28.12°C
# Temperature 31.02°C
# Temperature 39.24°C
# Temperature 6.03°C
# Temperature 17.75°C
# Temperature 23.74°C
# Temperature 20.77°C
# Temperature 32.07°C
# Temperature 33.97°C
# Temperature 9.66°C
# Temperature 11.48°C
# Temperature 17.26°C
# Temperature 10.44°C
# Temperature 4.25°C
# Temperature 3.54°C
# Temperature 36.18°C
# Temperature 12.67°C
# Temperature 0.64°C
# Temperature 2.68°C
# Temperature 19.45°C
# Temperature 34.11°C
# Temperature 20.21°C
# Temperature 13.22°C
# Temperature 23.13°C
# Temperature 27.83°C
# Temperature 21.19°C
# Temperature 24.78°C
# Temperature 18.99°C
# Temperature 33.01°C
# Temperature 18.84°C
# Temperature 1.1°C
# Temperature 35.1°C
# Temperature 10.44°C
# Temperature 4.24°C
# Temperature 23.59°C
# Temperature 12.84°C
# Temperature 8.29°C
# Temperature 17.57°C
# Temperature 4.41°C
# Temperature 12.91°C
# Temperature 31.93°C
# Temperature 18.26°C
# Temperature 14.91°C
# Temperature 10.97°C
# Temperature 39.13°C
# Temperature 10.86°C
# Temperature 8.24°C
# Temperature 13.22°C
# Temperature 25.77°C
# Temperature 34.94°C
# Temperature 27.09°C
# Temperature 37.04°C
# Temperature 39.77°C
# Temperature 26.68°C
# Temperature 5.53°C
# Temperature 22.96°C
# Temperature 24.04°C
# Temperature 36.78°C
# Temperature 1.11°C
# Temperature 6.97°C
# Temperature 3.89°C
# Temperature 2.06°C
# Temperature 39.22°C
# Temperature 3.16°C
# Temperature 11.92°C
# Temperature 4.84°C
# Temperature 2.87°C
# Temperature 31.91°C
# Temperature 4.83°C
# Temperature 9.26°C
# Temperature 4.73°C
# Temperature 22.47°C
# Temperature 39.2°C
# Temperature 36.5°C
# Temperature 33.98°C
# Temperature 16.32°C
# Temperature 25.52°C
# Temperature 1.57°C
# Temperature 32.03°C
# Temperature 13.56°C
# Temperature 33.39°C
# Temperature 30.33°C
# Temperature 27.84°C
# Temperature 20.88°C
# Temperature 29.28°C
# Temperature 13.27°C
# Temperature 0.51°C
# Temperature 37.65°C
# Temperature 18.49°C
# Temperature 7.63°C
# Temperature 25.34°C
# Temperature 10.48°C
# Temperature 8.99°C
# Temperature 38.38°C
# Temperature 24.35°C
# Temperature 23.57°C
# Temperature 15.05°C
# Temperature 25.12°C
# Temperature 34.97°C
# Temperature 18.78°C
# Temperature 5.95°C
# Temperature 0.24°C
# Temperature 8.97°C
# Temperature 0.9°C
# Temperature 12.16°C
# Temperature 27.91°C
# Temperature 36.33°C
# Temperature 18.91°C
# Temperature 3.26°C
# Temperature 11.54°C
# Temperature 3.91°C
# Temperature 19.86°C
# Temperature 20.89°C
# Temperature 21.81°C
# Temperature 18.4°C
# Temperature 27.55°C
# Temperature 32.87°C
# Temperature 29.04°C
# Temperature 23.09°C
# Temperature 19.77°C
# Temperature 35.77°C
# Temperature 35.97°C
# Temperature 27.85°C
# Temperature 30.85°C
# Temperature 13.29°C
# Temperature 19.53°C
# Temperature 22.63°C
# Temperature 13.04°C
# Temperature 30.04°C
# Temperature 3.15°C
# Temperature 11.27°C
# Temperature 31.21°C
# Temperature 16.49°C
# Temperature 1.81°C
# Temperature 24.08°C
# Temperature 25.06°C
# Temperature 9.33°C
# Temperature 17.33°C
# Temperature 5.79°C
# Temperature 4.76°C
# Temperature 5.55°C
# Temperature 8.79°C
# Temperature 33.03°C
# Temperature 16.28°C
# Temperature 1.86°C
# Temperature 28.8°C
# Temperature 35.64°C
# Temperature 18.95°C
# Temperature 4.99°C
# Temperature 39.36°C
# Temperature 20.15°C
# Temperature 11.38°C
# Temperature 38.47°C
# Temperature 13.82°C
# Temperature 35.24°C
# Temperature 35.1°C
# Temperature 33.74°C
# Temperature 11.48°C
# Temperature 26.23°C
# Temperature 6.22°C
# Temperature 30.28°C
# Temperature 0.56°C
# Temperature 3.85°C
# Temperature 39.94°C
# Temperature 1.95°C
# Temperature 24.94°C
# Temperature 24.26°C
# Temperature 26.57°C
# Temperature 10.42°C
# Temperature 29.01°C
# Temperature 30.04°C
# Temperature 29.55°C
# Temperature 7.33°C
# Temperature 6.84°C
# Temperature 18.35°C
# Temperature 4.78°C
# Temperature 32.13°C
# Temperature 9.44°C
# Temperature 0.62°C
# Temperature 0.96°C
# Temperature 36.31°C
# Temperature 16.44°C
# Temperature 35.38°C
# Temperature 23.14°C
# Temperature 36.02°C
# Temperature 6.38°C
# Temperature 0.99°C
# Temperature 30.07°C
# Temperature 38.07°C
# Temperature 1.59°C
# Temperature 34.76°C
# Temperature 26.69°C
# Temperature 2.13°C
# Temperature 28.78°C
# Temperature 38.3°C
# Temperature 18.46°C
# Temperature 21.77°C
# Temperature 19.05°C
# Temperature 39.65°C
# Temperature 7.53°C
# Temperature 36.83°C
# Temperature 0.14°C
# Temperature 37.94°C
# Temperature 21.79°C
# Temperature 24.18°C
# Temperature 6.61°C
# Temperature 37.07°C
# Temperature 36.25°C
# Temperature 12.24°C
# Temperature 30.67°C
# Temperature 2.29°C
# Temperature 25.1°C
# Temperature 25.41°C
# Temperature 26.75°C
# Temperature 23.82°C
# Temperature 18.0°C
# Temperature 13.98°C
# Temperature 38.53°C
# Temperature 28.84°C
# Temperature 14.61°C
# Temperature 12.45°C
# Temperature 20.77°C
# Temperature 18.54°C
# Temperature 7.36°C
# Temperature 28.05°C
# Temperature 34.8°C
# Temperature 7.41°C
# Temperature 17.37°C
# Temperature 25.28°C
# Temperature 17.69°C
# Temperature 37.78°C
# Temperature 11.62°C
# Temperature 13.87°C
# Temperature 15.22°C
# Temperature 34.84°C
# Temperature 32.82°C
# Temperature 6.57°C
# Temperature 17.38°C
# Temperature 9.96°C
# Temperature 12.39°C
# Temperature 26.23°C
# Temperature 19.36°C
# Temperature 18.04°C
# Temperature 27.61°C
# Temperature 11.94°C
# Temperature 17.66°C
# Temperature 18.82°C
# Temperature 39.72°C
# Temperature 26.62°C
# Temperature 34.18°C
# Temperature 34.49°C
# Temperature 37.09°C
# Temperature 2.98°C
# Temperature 36.18°C
# Temperature 20.07°C
# Temperature 0.78°C
# Temperature 7.43°C
# Temperature 20.91°C
# Temperature 25.99°C
# Temperature 14.65°C
# Temperature 20.79°C
# Temperature 31.13°C
# Temperature 9.18°C
# Temperature 31.35°C
# Temperature 12.85°C
# Temperature 7.99°C
# Temperature 23.36°C
# Temperature 34.64°C
# Temperature 27.64°C
# Temperature 21.19°C
# Temperature 32.76°C
# Temperature 5.58°C
# Temperature 32.83°C
# Temperature 3.39°C
# Temperature 23.27°C
# Temperature 0.73°C
# Temperature 31.75°C
# Temperature 27.7°C
# Temperature 1.63°C
# Temperature 12.42°C
# Temperature 27.44°C
# Temperature 21.23°C
# Temperature 38.55°C
# Temperature 31.25°C
# Temperature 7.37°C
# Temperature 33.31°C
# Temperature 12.89°C
# Temperature 0.33°C
# Temperature 37.07°C
# Temperature 35.82°C
# Temperature 5.86°C
# Temperature 34.75°C
# Temperature 20.5°C
# Temperature 38.77°C
# Temperature 37.32°C
# Temperature 30.69°C
# Temperature 7.44°C
# Temperature 35.0°C
# Temperature 19.89°C
# Temperature 37.37°C
# Temperature 7.93°C
# Temperature 16.55°C
# Temperature 13.46°C
# Temperature 0.29°C
# Temperature 12.58°C
# Temperature 7.94°C
# Temperature 30.55°C
# Temperature 1.05°C
# Temperature 18.37°C
# Temperature 15.73°C
# Temperature 10.15°C
# Temperature 0.29°C
# Temperature 33.31°C
# Temperature 26.19°C
# Temperature 8.05°C
# Temperature 31.58°C
# Temperature 25.19°C
# Temperature 25.13°C
# Temperature 26.63°C
# Temperature 28.93°C
# Temperature 4.82°C
# Temperature 2.76°C
# Temperature 6.19°C
# Temperature 9.18°C
# Temperature 34.1°C
# Temperature 4.73°C
# Temperature 0.54°C
# Temperature 0.73°C
# Temperature 4.59°C
# Temperature 13.75°C
# Temperature 29.43°C
# Temperature 29.66°C
# Temperature 35.38°C
# Temperature 13.82°C
# Temperature 26.0°C
# Temperature 18.72°C
# Temperature 14.1°C
# Temperature 6.2°C
# Temperature 9.49°C
# Temperature 18.97°C
# Temperature 1.03°C
# Temperature 39.62°C
# Temperature 26.21°C
# Temperature 3.55°C
# Temperature 39.08°C
# Temperature 4.97°C
# Temperature 21.62°C
# Temperature 14.2°C
# Temperature 10.64°C
# Temperature 14.06°C
# Temperature 30.62°C
# Temperature 2.8°C
# Temperature 20.06°C
# Temperature 38.84°C
# Temperature 27.81°C
# Temperature 24.31°C
# Temperature 24.07°C
# Temperature 26.41°C
# Temperature 22.26°C
# Temperature 22.46°C
# Temperature 8.48°C
# Temperature 29.57°C
# Temperature 25.54°C
# Temperature 7.31°C
# Temperature 8.72°C
# Temperature 14.64°C
# Temperature 22.51°C
# Temperature 30.9°C
# Temperature 7.05°C
# Temperature 27.97°C
# Temperature 32.28°C
# Temperature 31.96°C
# Temperature 16.47°C
# Temperature 29.32°C
# Temperature 15.94°C
# Temperature 25.4°C
# Temperature 28.0°C
# Temperature 27.07°C
# Temperature 3.71°C
# Temperature 33.99°C
# Temperature 21.01°C
# Temperature 22.22°C
# Temperature 2.26°C
# Temperature 27.65°C
# Temperature 12.66°C
# Temperature 0.47°C
# Temperature 17.51°C
# Temperature 19.16°C
# Temperature 36.59°C
# Temperature 20.08°C
# Temperature 22.19°C
# Temperature 5.64°C
# Temperature 2.01°C
# Temperature 18.79°C
# Temperature 20.11°C
# Temperature 33.94°C
# Temperature 22.65°C
# Temperature 3.17°C
# Temperature 37.33°C
# Temperature 34.16°C
# Temperature 20.03°C
# Temperature 21.84°C
# Temperature 39.2°C
# Temperature 19.08°C
# Temperature 24.45°C
# Temperature 30.97°C
# Temperature 18.05°C
# Temperature 21.98°C
# Temperature 31.55°C
# Temperature 10.08°C
# Temperature 18.51°C
# Temperature 32.02°C
# Temperature 30.85°C
# Temperature 37.58°C
# Temperature 28.5°C
# Temperature 19.4°C
# Temperature 36.4°C
# Temperature 1.95°C
# Temperature 28.3°C
# Temperature 31.38°C
# Temperature 11.92°C
# Temperature 34.51°C
# Temperature 31.93°C
# Temperature 13.89°C
# Temperature 16.97°C
# Temperature 19.07°C
# Temperature 19.81°C
# Temperature 8.04°C
# Temperature 39.77°C
# Temperature 27.14°C
# Temperature 19.43°C
# Temperature 20.59°C
# Temperature 28.24°C
# Temperature 35.56°C
# Temperature 12.03°C
# Temperature 22.96°C
# Temperature 25.59°C
# Temperature 36.97°C
# Temperature 12.01°C
# Temperature 3.28°C
# Temperature 19.98°C
# Temperature 26.94°C
# Temperature 1.84°C
# Temperature 22.23°C
# Temperature 30.76°C
# Temperature 26.12°C
# Temperature 12.29°C
# Temperature 12.93°C
# Temperature 17.26°C
# Temperature 25.42°C
# Temperature 8.99°C
# Temperature 28.41°C
# Temperature 11.77°C
# Temperature 39.92°C
# Temperature 16.06°C
# Temperature 11.68°C
# Temperature 6.6°C
# Temperature 27.79°C
# Temperature 33.62°C
# Temperature 32.08°C
# Temperature 10.51°C
# Temperature 13.94°C
# Temperature 11.86°C
# Temperature 23.86°C
# Temperature 20.46°C
# Temperature 21.98°C
# Temperature 30.52°C
# Temperature 11.93°C
# Temperature 12.17°C
# Temperature 38.28°C
# Temperature 10.97°C
# Temperature 24.69°C
# Temperature 39.19°C
# Temperature 15.16°C
# Temperature 35.72°C
# Temperature 18.91°C
# Temperature 35.52°C
# Temperature 24.46°C
# Temperature 33.02°C
# Temperature 30.24°C
# Temperature 3.56°C
# Temperature 19.42°C
# Temperature 7.99°C
# Temperature 26.8°C
# Temperature 10.33°C
# Temperature 6.2°C
# Temperature 22.31°C
# Temperature 35.88°C
# Temperature 7.99°C
# Temperature 12.77°C
# Temperature 10.43°C
# Temperature 6.75°C
# Temperature 28.47°C
# Temperature 24.25°C
# Temperature 37.2°C
# Temperature 30.84°C
# Temperature 4.38°C
# Temperature 25.04°C
# Temperature 16.63°C
# Temperature 8.02°C
# Temperature 10.2°C
# Temperature 22.73°C
# Temperature 26.29°C
# Temperature 25.96°C
# Temperature 19.95°C
# Temperature 18.82°C
# Temperature 30.15°C
# Temperature 4.12°C
# Temperature 9.81°C
# Temperature 34.59°C
# Temperature 37.28°C
# Temperature 8.93°C
# Temperature 5.07°C
# Temperature 13.29°C
# Temperature 25.5°C
# Temperature 35.99°C
# Temperature 9.41°C
# Temperature 26.31°C
# Temperature 28.35°C
# Temperature 36.04°C
# Temperature 1.08°C
# Temperature 31.33°C
# Temperature 23.65°C
# Temperature 25.86°C
# Temperature 0.02°C
# Temperature 33.19°C
# Temperature 21.48°C
# Temperature 29.51°C
# Temperature 25.51°C
# Temperature 16.82°C
# Temperature 20.46°C
# Temperature 3.51°C
# Temperature 28.41°C
# Temperature 27.84°C
# Temperature 29.02°C
# Temperature 14.48°C
# Temperature 33.19°C
# Temperature 0.82°C
# Temperature 2.79°C
# Temperature 19.95°C
# Temperature 13.44°C
# Temperature 29.79°C
# Temperature 0.88°C
# Temperature 0.41°C
# Temperature 2.4°C
# Temperature 29.86°C
# Temperature 13.82°C
# Temperature 28.5°C
# Temperature 22.04°C
# Temperature 17.47°C
# Temperature 30.37°C
# Temperature 21.58°C
# Temperature 18.34°C
# Temperature 4.99°C
# Temperature 39.81°C
# Temperature 24.26°C
# Temperature 39.92°C
# Temperature 16.2°C
# Temperature 31.4°C
# Temperature 36.71°C
# Temperature 32.78°C
# Temperature 8.25°C
# Temperature 38.09°C
# Temperature 24.86°C
# Temperature 37.83°C
# Temperature 23.13°C
# Temperature 22.63°C
# Temperature 9.36°C
# Temperature 12.31°C
# Temperature 30.77°C
# Temperature 25.09°C
# Temperature 16.11°C
# Temperature 8.97°C
# Temperature 0.73°C
# Temperature 6.09°C
# Temperature 36.32°C
# Temperature 26.42°C
# Temperature 22.9°C
# Temperature 8.69°C
# Temperature 36.08°C
# Temperature 13.49°C
# Temperature 7.78°C
# Temperature 14.59°C
# Temperature 30.76°C
# Temperature 26.52°C
# Temperature 36.76°C
# Temperature 16.61°C
# Temperature 37.58°C
# Temperature 24.79°C
# Temperature 29.97°C
# Temperature 3.21°C
# Temperature 2.59°C
# Temperature 28.78°C
# Temperature 38.27°C
# Temperature 6.0°C
# Temperature 38.04°C
# Temperature 4.52°C
# Temperature 8.58°C
# Temperature 14.82°C
# Temperature 21.26°C
# Temperature 1.27°C
# Temperature 9.43°C
# Temperature 9.71°C
# Temperature 14.68°C
# Temperature 15.1°C
# Temperature 17.78°C
# Temperature 18.28°C
# Temperature 30.2°C
# Temperature 12.37°C
# Temperature 38.55°C
# Temperature 6.14°C
# Temperature 36.68°C
# Temperature 7.92°C
# Temperature 31.23°C
# Temperature 9.39°C
# Temperature 10.2°C
# Temperature 0.8°C
# Temperature 21.32°C
# Temperature 9.82°C
# Temperature 38.12°C
# Temperature 17.73°C
# Temperature 27.38°C
# Temperature 23.26°C
# Temperature 7.98°C
# Temperature 3.15°C
# Temperature 12.44°C
# Temperature 23.9°C
# Temperature 27.06°C
# Temperature 37.47°C
# Temperature 28.41°C
# Temperature 18.44°C
# Temperature 5.03°C
# Temperature 37.6°C
# Temperature 15.58°C
# Temperature 13.87°C
# Temperature 25.94°C
# Temperature 28.39°C
# Temperature 3.16°C
# Temperature 34.89°C
# Temperature 22.71°C
# Temperature 1.22°C
# Temperature 9.69°C
# Temperature 37.95°C
# Temperature 28.27°C
# Temperature 29.21°C
# Temperature 26.05°C
# Temperature 30.89°C
# Temperature 25.72°C
# Temperature 17.28°C
# Temperature 13.17°C
# Temperature 4.59°C
# Temperature 35.65°C
# Temperature 30.22°C
# Temperature 36.65°C
# Temperature 10.09°C
# Temperature 12.08°C
# Temperature 34.8°C
# Temperature 0.16°C
# Temperature 28.31°C
# Temperature 38.42°C
# Temperature 29.92°C
# Temperature 26.98°C
# Temperature 11.32°C
# Temperature 28.66°C
# Temperature 15.09°C
# Temperature 22.43°C
# Temperature 30.84°C
# Temperature 27.11°C
# Temperature 33.47°C
# Temperature 1.34°C
# Temperature 1.47°C
# Temperature 37.24°C
# Temperature 2.73°C
# Temperature 14.09°C
# Temperature 19.33°C
# Temperature 8.05°C
# Temperature 33.05°C
# Temperature 20.53°C
# Temperature 2.78°C
# Temperature 5.71°C
# Temperature 11.48°C
# Temperature 1.02°C
# Temperature 23.35°C
# Temperature 12.22°C
# Temperature 29.73°C
# Temperature 9.44°C
# Temperature 4.18°C
# Temperature 24.9°C
# Temperature 15.28°C
# Temperature 6.23°C
# Temperature 30.88°C
# Temperature 20.68°C
# Temperature 39.1°C
# Temperature 7.0°C
# Temperature 2.08°C
# Temperature 6.26°C
# Temperature 13.71°C
# Temperature 23.08°C
# Temperature 10.3°C
# Temperature 12.42°C
# Temperature 15.48°C
# Temperature 38.13°C
# Temperature 34.19°C
# Temperature 24.76°C
# Temperature 7.0°C
# Temperature 9.14°C
# Temperature 16.02°C
# Temperature 28.57°C
# Temperature 26.57°C
# Temperature 19.23°C
# Temperature 0.49°C
# Temperature 36.81°C
# Temperature 31.54°C
# Temperature 25.84°C
# Temperature 17.84°C
# Temperature 3.95°C
# Temperature 22.61°C
# Temperature 10.43°C
# Temperature 17.03°C
# Temperature 25.27°C
# Temperature 14.2°C
# Temperature 9.15°C
# Temperature 6.76°C
# Temperature 20.31°C
# Temperature 11.89°C
# Temperature 25.78°C
# Temperature 26.47°C
# Temperature 25.79°C
# Temperature 29.63°C
# Temperature 21.1°C
# Temperature 25.62°C
# Temperature 32.45°C
# Temperature 4.61°C
# Temperature 8.17°C
# Temperature 13.09°C
# Temperature 2.15°C
# Temperature 4.91°C
# Temperature 7.86°C
# Temperature 14.37°C
# Temperature 21.61°C
# Temperature 15.46°C
# Temperature 5.66°C
# Temperature 32.54°C
# Temperature 19.19°C
# Temperature 0.95°C
# Temperature 0.33°C
# Temperature 5.32°C
# Temperature 20.59°C
# Temperature 12.92°C
# Temperature 14.62°C
# Temperature 33.8°C
# Temperature 10.25°C
# Temperature 1.18°C
# Temperature 2.57°C
# Temperature 2.82°C
# Temperature 15.56°C
# Temperature 27.02°C
# Temperature 20.86°C
# Temperature 33.3°C
# Temperature 33.08°C
# Temperature 14.06°C
# Temperature 8.19°C
# Temperature 13.36°C
# Temperature 4.45°C
# Temperature 15.49°C
# Temperature 20.1°C
# Temperature 17.68°C
# Temperature 18.58°C
# Temperature 1.52°C
# Temperature 24.37°C
# Temperature 30.73°C
# Temperature 31.85°C
# Temperature 3.84°C
# Temperature 10.69°C
# Temperature 6.02°C
# Temperature 36.93°C
# Temperature 23.95°C
# Temperature 10.37°C
# Temperature 3.2°C
# Temperature 12.82°C
# Temperature 31.85°C
# Temperature 36.08°C
# Temperature 34.18°C
# Temperature 3.54°C
# Temperature 24.59°C
# Temperature 14.98°C
# Temperature 26.55°C
# Temperature 0.39°C
# Temperature 39.3°C
# Temperature 0.79°C
# Temperature 35.52°C
# Temperature 0.97°C
# Temperature 34.54°C
# Temperature 15.19°C
# Temperature 8.86°C
# Temperature 7.29°C
# Temperature 8.16°C
# Temperature 3.54°C
# Temperature 25.99°C
# Temperature 22.15°C
# Temperature 18.47°C
# Temperature 27.71°C
# Temperature 19.93°C
# Temperature 2.13°C
# Temperature 24.8°C
# Temperature 12.43°C
# Temperature 6.51°C
# Temperature 16.32°C
# Temperature 18.1°C
# Temperature 21.45°C
# Temperature 9.24°C
# Temperature 33.1°C
# Temperature 3.52°C
# Temperature 3.09°C
# Temperature 23.27°C
# Temperature 13.93°C
# Temperature 13.97°C
# Temperature 35.13°C
# Temperature 18.84°C
# Temperature 4.15°C
# Temperature 12.52°C
# Temperature 22.39°C
# Temperature 22.86°C
# Temperature 28.05°C
# Temperature 13.19°C
# Temperature 1.27°C
# Temperature 23.45°C
# Temperature 12.0°C
# Temperature 2.98°C
# Temperature 5.26°C
# Temperature 29.38°C
# Temperature 5.46°C
# Temperature 28.78°C
# Temperature 1.19°C
# Temperature 16.11°C
# Temperature 30.26°C
# Temperature 17.85°C
# Temperature 2.62°C
# Temperature 35.54°C
# Temperature 29.99°C
# Temperature 37.39°C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 while True:
# ----> 2     _, temp = sensor.read()
#       3     print(f'Temperature {temp}°C')
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/counterfit_shims_seeed_python_dht.py:41, in DHT.read(self, retries)
#      37 def read(self, retries = 15):
#      38     '''
#      39     Read the humidity and temperature from the sensor
#      40     '''
# ---> 41     humidity = CounterFitConnection.get_sensor_float_value(self.__humidity_pin)
#      42     temperature = CounterFitConnection.get_sensor_float_value(self.__temperature_pin)
#      44     return humidity, temperature
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/counterfit_connection.py:49, in CounterFitConnection.get_sensor_float_value(port)
#      44 @staticmethod
#      45 def get_sensor_float_value(port: int) -> float:
#      46     '''
#      47     Reads a float value from the sensor on the given port
#      48     '''
# ---> 49     response = requests.get(CounterFitConnection.base_url + 'sensor_value?port=' + str(port))
#      50     return float(response.json()['value'])
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/playground/lec-iot-for-beginners/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/miniconda3/lib/python3.11/http/client.py:337, in HTTPResponse.begin(self)
#     334 else:
#     335     raise UnknownProtocol(version)
# --> 337 self.headers = self.msg = parse_headers(self.fp)
#     339 if self.debuglevel > 0:
#     340     for hdr, val in self.headers.items():
#
# File ~/miniconda3/lib/python3.11/http/client.py:236, in parse_headers(fp, _class)
#     234 headers = _read_headers(fp)
#     235 hstring = b''.join(headers).decode('iso-8859-1')
# --> 236 return email.parser.Parser(_class=_class).parsestr(hstring)
#
# File ~/miniconda3/lib/python3.11/email/parser.py:67, in Parser.parsestr(self, text, headersonly)
#      59 def parsestr(self, text, headersonly=False):
#      60     """Create a message structure from a string.
#      61
#      62     Returns the root of the message structure.  Optional headersonly is a
#    (...)
#      65     the file.
#      66     """
# ---> 67     return self.parse(StringIO(text), headersonly=headersonly)
#
# File ~/miniconda3/lib/python3.11/email/parser.py:56, in Parser.parse(self, fp, headersonly)
#      54     if not data:
#      55         break
# ---> 56     feedparser.feed(data)
#      57 return feedparser.close()
#
# File ~/miniconda3/lib/python3.11/email/feedparser.py:174, in FeedParser.feed(self, data)
#     172 """Push more data into the parser."""
#     173 self._input.push(data)
# --> 174 self._call_parse()
#
# File ~/miniconda3/lib/python3.11/email/feedparser.py:178, in FeedParser._call_parse(self)
#     176 def _call_parse(self):
#     177     try:
# --> 178         self._parse()
#     179     except StopIteration:
#     180         pass
#
# File ~/miniconda3/lib/python3.11/email/feedparser.py:254, in FeedParser._parsegen(self)
#     252     self._cur.set_payload(EMPTYSTRING.join(lines))
#     253     return
# --> 254 if self._cur.get_content_type() == 'message/delivery-status':
#     255     # message/delivery-status contains blocks of headers separated by
#     256     # a blank line.  We'll represent each header block as a separate
#     257     # nested message object, but the processing is a bit different
#     258     # than standard message/* types because there is no body for the
#     259     # nested messages.  A blank line separates the subparts.
#     260     while True:
#     261         self._input.push_eof_matcher(NLCRE.match)
#
# File ~/miniconda3/lib/python3.11/email/message.py:605, in Message.get_content_type(self)
#     592 """Return the message's content type.
#     593
#     594 The returned string is coerced to lower case of the form
#    (...)
#     602 message/rfc822.
#     603 """
#     604 missing = object()
# --> 605 value = self.get('content-type', missing)
#     606 if value is missing:
#     607     # This should have no parameters
#     608     return self.get_default_type()
#
# File ~/miniconda3/lib/python3.11/email/message.py:498, in Message.get(self, name, failobj)
#     496 for k, v in self._headers:
#     497     if k.lower() == name:
# --> 498         return self.policy.header_fetch_parse(k, v)
#     499 return failobj
#
# File ~/miniconda3/lib/python3.11/email/_policybase.py:316, in Compat32.header_fetch_parse(self, name, value)
#     311 def header_fetch_parse(self, name, value):
#     312     """+
#     313     If the value contains binary data, it is converted into a Header object
#     314     using the unknown-8bit charset.  Otherwise it is returned unmodified.
#     315     """
# --> 316     return self._sanitize_header(name, value)
#
# File ~/miniconda3/lib/python3.11/email/_policybase.py:287, in Compat32._sanitize_header(self, name, value)
#     284 if not isinstance(value, str):
#     285     # Assume it is already a header object
#     286     return value
# --> 287 if _has_surrogates(value):
#     288     return header.Header(value, charset=_charset.UNKNOWN8BIT,
#     289                          header_name=name)
#     290 else:
#
# File ~/miniconda3/lib/python3.11/email/utils.py:51, in _has_surrogates(s)
#      48 specialsre = re.compile(r'[][\\()<>@,:;".]')
#      49 escapesre = re.compile(r'[\\"]')
# ---> 51 def _has_surrogates(s):
#      52     """Return True if s contains surrogate-escaped binary data."""
#      53     # This check is based on the fact that unless there are surrogates, utf8
#      54     # (Python's default encoding) can encode any string.  This is the fastest
#      55     # way to check for surrogates, see issue 11454 for timings.
#
# KeyboardInterrupt:

# %% [markdown]
# 1. Adicione um pequeno sleep de dez segundos no final do `loop`, pois os níveis de temperatura não precisam ser verificados continuamente. Um sleep reduz o consumo de energia do dispositivo.
#
#     ```Python
#     time.sleep(10)
#     ```

# %%
while True:
    _, temp = sensor.read()
    print(f'Temperature {temp}°C')
    time.sleep(10)
# Out:
# Temperature 29.67°C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 _, temp = sensor.read()
#       3 print(f'Temperature {temp}°C')
# ----> 4 time.sleep(10)
#
# KeyboardInterrupt:

# %% [markdown]
# 1. No Terminal do VS Code com um ambiente virtual ativado, execute o seguinte para executar seu aplicativo Python:
#
#     ```sh
#     python app.py
#     ```
#
# 1. No aplicativo CounterFit, altere o valor do sensor de temperatura que será lido pelo aplicativo. Você pode fazer isso de duas maneiras:
#
#     * Insira um número na caixa *Value* para o sensor de temperatura e, em seguida, selecione o botão **Set**. O número que você inserir será o valor retornado pelo sensor.
#
#     * Marque a caixa de seleção *Random* e insira um valor *Min* e *Max*, depois selecione o botão **Set**. Toda vez que o sensor ler um valor, ele lerá um número aleatório entre *Min* e *Max*.
#
#     Você deve ver os valores que você definiu aparecendo no console. Altere as configurações *Value* ou *Random* para ver a mudança de valor.
#
#     ```saída
#     (.venv) ➜ temperature-sensor python app.py
#     Temperatura 28,25°C
#     Temperatura 30,71°C
#     Temperatura 25,17°C
#     ```
#
# > 💁 Você pode encontrar este código na pasta [code-temperature/virtual-device](https://github.com/microsoft/IoT-For-Beginners/blob/main/2-farm/lessons/1-predict-plant-growth/code-temperature/virtual-device).
#
# 😀 Seu programa de sensor de temperatura foi um sucesso!
