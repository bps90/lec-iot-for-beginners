# %% [markdown]
# # Project nightlight - Hello World
#
# ![Alt Text](https://media.giphy.com/media/kwCL0wIRPuO6loPGQ7/giphy.gif)

# %% [markdown]
# ### 1 - Instalando o CounterFit (simulador de sensores/atuadores)
#
# Para maiores detalhes https://github.com/microsoft/IoT-For-Beginners/blob/main/1-getting-started/lessons/1-introduction-to-iot/virtual-device.md

# %% [markdown]
# ![CounterFitLogo.png](attachment:5a6fcdce-b042-456c-b1e7-5979ddcbac42.png)![68747470733a2f2f6d656469612e67697068792e636f6d2f6d656469612f336f37714531594e3761424f4650527738452f67697068792e676966.gif](attachment:bf8d4036-c4ec-4d30-9c9a-94226c82c57a.gif)

# %% [markdown]
# Basicamente é necessário executar os seguintes comandos:
# > pip install CounterFit
#
# > pip install counterfit-connection
#
# > pip install counterfit-shims-grove

# %% [markdown]
# ## 2 - Executando CounterFit

# %% [markdown]
# O Counterfit funciona como um servidor, o qual possui interface web e opera, por padrão, na porta 5000.
# - Para executar o Counterfit execute o seguinte comando no terminal:
# >  counterfit
#
# O terminal exibirá algo como:
#
# ![image.png](attachment:9bb3ef8a-7e34-446c-beb4-30b8bdd2559a.png)![image.png](attachment:67bfb312-5ff3-4754-a60a-f17303da83e8.png)

# %% [markdown]
# - Para acessar a interface web, abra o navegador e digite:
# > localhost:5000
#
# Será exibido algo como:
#
# ![image.png](attachment:f4f5d073-14d2-4952-b85e-90e7d377f5bf.png)

# %% [markdown]
# ## 3 - Hello World

# %%
from counterfit_connection import CounterFitConnection

CounterFitConnection.init('127.0.0.1', 5000)

print('Hello World!')
# Out:
# Hello World!
